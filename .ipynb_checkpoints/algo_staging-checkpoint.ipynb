# %% [markdown]
# #### Import / Global Vars

# %%
#imports section
import pandas_datareader.data as web
import numpy as np
import pandas as pd
import cvxpy as cvx
import re, os
import matplotlib.pyplot as plt
from math import *
from datetime import datetime, date, time, timedelta
from time import sleep
from mvo_utils import *
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# Global variables
log = True
active_bench = 'spy_sectors' # 'spy_sectors OR 'ark_etfs'
active_etf = None # ETF name OR None for broad market
#variables for performance analysis
frequency = "W-FRI"; lb = 20 # initial value for lookback
min_gross=0.5; max_gross=1; min_w=0; max_w=0.1 # default optimization vars

# %% [markdown]
# #### Load sector components from hard-drive

# %%
# load spy sector components
# would be nice to load a JSON with configuration
config = {
    'spy_sectors' : {
        'hold_cols': ['Symbol','Company Name', 'Index Weight'],
        'hold_format': r'holdings-spy-',
        'idx_col': 'Symbol',
        'fname': 'spy-sectors',
        'skiprows': 1
    },
    'ark_etfs' : {
        'hold_cols': ['ticker','company', 'weight(%)'],
        'hold_format': r'holdings-ark-',
        'idx_col': 'ticker',
        'fname': 'ark-etfs',
        'skiprows': 0
    }
}

hold_cols = config[active_bench]['hold_cols']
hold_format = config[active_bench]['hold_format']
idx_col = config[active_bench]['idx_col']
fname = config[active_bench]['fname']
skiprows = config[active_bench]['skiprows']

companies = load_components(
    companies, hold_format, hold_cols, 
    idx_col, ticker_map[active_bench], srows=skiprows)
print("Companies loaded:", companies.shape)
px_etfs = load_pricing(fname + '.csv', 'Date')
px_spy = load_pricing('SPY.csv', 'Date')
# Out:
# Companies loaded: (179, 3)
# Loaded pricing for ark-etfs.csv, with shape (843, 4)
# Loaded pricing for SPY.csv, with shape (68, 1)

# %%
px_etfs.info()
compound(px_etfs).plot(fontsize='small')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 843 entries, 2014-09-30 to 2018-02-02
# Data columns (total 4 columns):
# ARKG    820 non-null float64
# ARKK    820 non-null float64
# ARKQ    842 non-null float64
# ARKW    843 non-null float64
# dtypes: float64(4)
# memory usage: 32.9 KB

# %%
# Load pricing for components of each sectors
# Util function to load components for different benchmarks
def load_consol_px(tm_key):
    consol_px = pd.DataFrame([])
    for key in ticker_map[tm_key]:
        px = load_pricing(key + '-hold-pricing.csv', 'Date')[frame:].copy()
        ccols = set(consol_px.columns.tolist())
        newcols = set(px.columns.tolist())
        consol_px = consol_px.merge(
            px[list(newcols.difference(ccols))], 
            left_index=True, 
            right_index=True, 
            how='outer')
    return consol_px

consol_px = load_consol_px(active_bench)
if(active_etf != None):
    companies = companies[companies['ETF']==active_etf] # filter by selected ETF
tickers = companies.index.tolist()
consol_px = consol_px[tickers]
# Out:
# Loaded pricing for ARKG-hold-pricing.csv, with shape (209, 36)
# Loaded pricing for ARKK-hold-pricing.csv, with shape (209, 55)
# Loaded pricing for ARKQ-hold-pricing.csv, with shape (209, 45)
# Loaded pricing for ARKW-hold-pricing.csv, with shape (209, 43)

# %% [markdown]
# #### Get Data from the Server

# %%
# New approach using dynamic key lookup name
"""
etfs = [e for e in ticker_map[active_bench]]
refresh_components(etfs)
get_safe_pricing(active_bench + '.csv', ticker_map[active_bench], start_date)
get_safe_pricing('SPY.csv', ['SPY'], start_date)
px_etfs = load_pricing(active_bench + '.csv', 'Date')
px_spy = load_pricing('SPY.csv', 'Date')
"""
# Out:
# "\netfs = [e for e in ticker_map[active_bench]]\nrefresh_components(etfs)\nget_safe_pricing(active_bench + '.csv', ticker_map[active_bench], start_date)\nget_safe_pricing('SPY.csv', ['SPY'], start_date)\npx_etfs = load_pricing(active_bench + '.csv', 'Date')\npx_spy = load_pricing('SPY.csv', 'Date')\n"

# %%
# Legacy approach
"""
spyder_etfs = [e for e in ticker_map['spy_sectors']]
ark_etfs = [e for e in ticker_map['ark_etfs']]
refresh_components(spyder_etfs)
#refresh_components(ark_etfs)
get_safe_pricing('spy-sectors.csv', ticker_map['spy_sectors'], start_date)
#get_safe_pricing('ark-etfs.csv', ticker_map['ark_etfs'], start_date)
get_safe_pricing('SPY.csv', ['SPY'], start_date)

px_spy_etfs = load_pricing('spy-sectors.csv', 'Date')
#px_ark_etfs = load_pricing('ark-etfs.csv', 'Date')
px_spy = load_pricing('SPY.csv', 'Date')
"""
# Out:
# "\nspyder_etfs = [e for e in ticker_map['spy_sectors']]\nark_etfs = [e for e in ticker_map['ark_etfs']]\nrefresh_components(spyder_etfs)\n#refresh_components(ark_etfs)\nget_safe_pricing('spy-sectors.csv', ticker_map['spy_sectors'], start_date)\n#get_safe_pricing('ark-etfs.csv', ticker_map['ark_etfs'], start_date)\nget_safe_pricing('SPY.csv', ['SPY'], start_date)\n\npx_spy_etfs = load_pricing('spy-sectors.csv', 'Date')\n#px_ark_etfs = load_pricing('ark-etfs.csv', 'Date')\npx_spy = load_pricing('SPY.csv', 'Date')\n"

# %% [markdown]
# #### Generate Trading Recomendations

# %%
# Removing tickers for M&A targets and diff class shares of same co.
remove_tickers = ['CSRA', 'DPS', 'UAA'] # example: two M&A targets, duplicate co. diff share class
if len(set(remove_tickers).intersection(consol_px.columns.tolist())) > 0:
    consol_px.drop(remove_tickers, axis=1, inplace=True)

# %%
# Finds the best gamma risk parameter
SAMPLES = 100
gamma_vals = np.logspace(-2, 3, num=SAMPLES)
opt_cols = ["Return", "Risk", "Sharpe"]
opt_df = pd.DataFrame([], index=gamma_vals, columns=opt_cols)

for i in gamma_vals:
    px_portion, _, alloc, pdf = recommend_allocs(
        consol_px, frame, lb, frequency, min_gross, max_gross, min_w, max_w, i)
    rec = last_allocation(alloc, 0.01)
    ret, risk = port_metrics(px_portion, rec)
    opt_df.loc[i][opt_cols] = [ret, risk, ret / risk]
top = 5; best_gamma_ports = opt_df.sort_values(by='Sharpe', ascending=False).head(top)
top_gammas = best_gamma_ports.index.tolist(); gamma_val = top_gammas[0]
portfolio_metrics('Benchmark', px_spy.loc[pdf.index]);
best_gamma_ports.head(top)
# Out:
# Benchmark Return: -0.03, StdDev: 0.06, Sharpe: -0.54
# /Users/vicveiga/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   from ipykernel import kernelapp as app
#               Return       Risk   Sharpe
# 13.530478   0.646122  0.0461995  13.9855
# 19.179103   0.513644  0.0391452  13.1215
# 24.201283   0.473759  0.0363118   13.047
# 21.544347   0.483532  0.0372114  12.9942
# 351.119173  0.130862   0.010103  12.9528

# %%
# Creates matrix of lookbacks and weights to determine the best combination
lbs = [x for x in range(5, 25, 5)]
ws = [y/100 for y in [x for x in range(5, 20, 5)]]

mtx_cols = ["Lookback", "Weight"]
mtx_cols.extend(opt_cols)
mtx_df = pd.DataFrame([], index=range(len(lbs) * len(ws)), columns=mtx_cols)

log = True; i = 0
for l in lbs:
    for w in ws:
        px_portion, _, alloc, _ = recommend_allocs(
            consol_px, frame, l, frequency, min_gross, max_gross, min_w, w, gamma_val)
        rec = last_allocation(alloc, 0.01); tickers = rec.index.tolist()
        ret, risk = port_metrics(px_portion, rec)
        mtx_df.loc[i][mtx_cols] = [l, w, ret, risk, ret / risk]
        i += 1

# %%
mtx_df = mtx_df.sort_values(by='Return', ascending=False)
lb, max_w = mtx_df.iloc[0]['Lookback'], mtx_df.iloc[0]['Weight']
print("Gamma: {0:.2f}, Lookback: {1}, Max Weight: {2}".format(gamma_val, lb, max_w))
# Out:
# Gamma: 13.53, Lookback: 20, Max Weight: 0.1

# %%
# what is the difference between port with gammas 1..5?
def rr_portfolios(g_list):
    best_ports = pd.DataFrame([], index=g_list)
    for g in g_list:
        _, _, alloc, _ = recommend_allocs(consol_px, frame, lb, frequency, min_gross, max_gross, min_w, max_w, g)
        rec = last_allocation(alloc, 0.01);
        df1 = pd.DataFrame(rec.T.values, index=[g], columns=rec.index.tolist())
        best_ports = best_ports.combine_first(df1)
    return best_ports
rr_portfolios(top_gammas[:top])
# Out:
#                 AMZN      ATHN  BCG     CTRP      MELI      MLNX      MSFT  \
# 13.530478   0.100000  0.100000  NaN      NaN  0.059318       NaN  0.038920
# 19.179103   0.100000  0.100000  NaN      NaN       NaN       NaN  0.037814
# 21.544347   0.100000  0.100000  NaN      NaN       NaN       NaN       NaN
# 24.201283   0.100000  0.100000  NaN      NaN       NaN       NaN       NaN
# 351.119173  0.056385  0.027952  0.1  0.06132       NaN  0.055024       NaN
#
#                 NFLX  NOW     NTDOY  SHOP      SPLK      TDOC      TSLA  \
# 13.530478   0.100000  0.1  0.020864   0.1       NaN  0.080898       NaN
# 19.179103   0.100000  0.1  0.013221   0.1       NaN  0.062486       NaN
# 21.544347   0.100000  0.1  0.018329   0.1       NaN  0.049843  0.010206
# 24.201283   0.100000  0.1  0.010300   0.1       NaN  0.039973  0.018351
# 351.119173  0.023282  0.1       NaN   NaN  0.016227       NaN  0.046254
#
#                  TSM  TWOU      TWTR
# 13.530478   0.100000   0.1  0.100000
# 19.179103   0.100000   0.1  0.096730
# 21.544347   0.100000   0.1  0.093091
# 24.201283   0.100000   0.1  0.085232
# 351.119173  0.013557   NaN       NaN

# %%
# run optimization with best gamma, returns initial weights
px_portion, returns, alloc, pdf = recommend_allocs(
    consol_px, frame, lb, frequency, min_gross, max_gross, min_w, max_w, gamma_val)
rec = last_allocation(alloc, 0.01)
tickers = rec.index.tolist()
recommend = rec.copy()
recommend['Sector'] = companies.loc[tickers]['ETF']
recommend['Company'] = companies.loc[tickers][['Company']]
recommend = recommend.astype({"Allocation": np.float})
recommend[['Company', 'Sector', 'Allocation']]
recommend
# Out:
#        Allocation Sector                      Company
# AMZN     0.100000   ARKW               AMAZON.COM INC
# NFLX     0.100000   ARKW                  NETFLIX INC
# TWTR     0.100000   ARKW                  TWITTER INC
# ATHN     0.100000   ARKW             ATHENAHEALTH INC
# TWOU     0.100000   ARKW                       2U INC
# MELI     0.059318   ARKW             MERCADOLIBRE INC
# SHOP     0.100000   ARKW        SHOPIFY INC - CLASS A
# NOW      0.100000   ARKW               SERVICENOW INC
# TSM      0.100000   ARKW  TAIWAN SEMICONDUCTOR-SP ADR
# NTDOY    0.020864   ARKW  NINTENDO CO LTD-UNSPONS ADR
# MSFT     0.038920   ARKW               MICROSOFT CORP
# TDOC     0.080898   ARKW                  TELADOC INC

# %%
# plots all tickers to verify if there are any M&A targets
for t in recommend.sort_index().index:
    consol_px[t][-frame:].plot()
    plt.title(companies.loc[t]['Company'])
    plt.show()

# %%
def sect_group_stats(col):
    re_group = recommend.groupby(by=col)
    print("Total % Allocation {0:.2f}".format(recommend.Allocation.sum() * 100));
    sector_cols = ['Sector Weight', 'Avg Position']
    sector_df = pd.DataFrame([], index=pd.unique(recommend[col]), columns=sector_cols)
    sector_df[sector_df.columns[0]] = re_group.sum()
    sector_df[sector_df.columns[1]] = re_group.mean()
    return sector_df
sect_group_stats('Sector')
# Out:
# Total % Allocation 100.00
#       Sector Weight  Avg Position
# ARKW            1.0      0.083333

# %%
compound(consol_px[recommend.index][-lb:]).plot()

# %%
# Outputs for trade execution
px = consol_px[recommend.index][-lb:]
date = px[-1:].index.to_datetime().strftime(date_fmt)[0]
ret, risk = port_metrics(px_portion, rec) # HAS AN ISSUE HERE INCONSISTEN ***

trading_cols = ['Company', 'Price', 'Allocation', 'Dollar Value', 'Shares']
trading_df = pd.DataFrame([], index=rec.index, columns=trading_cols)

round_shares = lambda x: round(x, 0)
port_bal = 227000; alloc = rec.T.values
pvalue = (port_bal * alloc)
shares = (port_bal * alloc) / px[-1:]
shares.apply(round_shares).T.sort_index()

trading_df['Company'] = recommend['Company']
trading_df['Price'] = px[-1:].T
trading_df['Allocation'] = recommend['Allocation']
trading_df['Dollar Value'] = trading_df['Allocation'] * port_bal
trading_df['Shares'] = trading_df['Dollar Value'] / trading_df['Price']

print("Frame: {}, Lookback: {}, MinGrossAlloc: {}, MaxGrossAlloc: {}, MinWeight: {}, MaxWeight: {}".format(frame, lb, min_gross, max_gross, min_w, max_w))
print("Ann. Ret: {0:.2f}, Risk: {1:.2f} Sharpe: {2:.2f}".format(ret, risk, ret / risk))
print("Date: {0}, Total Invested: {1:.2f}, Total Allocation: {2:.2f}".format(date, trading_df['Dollar Value'].sum(), trading_df['Allocation'].sum() * 100))

trading_df
# Show some basic metrics like date, total value invested, and sum total allocation
# Out:
# Frame: 20, Lookback: 20, MinGrossAlloc: 0.5, MaxGrossAlloc: 1, MinWeight: 0, MaxWeight: 0.1
# Ann. Ret: 0.65, Risk: 0.05 Sharpe: 13.99
# Date: 02-07-2018, Total Invested: 227000.00, Total Allocation: 100.00
#                            Company        Price  Allocation  Dollar Value  \
# AMZN                AMAZON.COM INC  1454.864990    0.100000  22699.999995
# NFLX                   NETFLIX INC   270.285004    0.100000  22699.999998
# TWTR                   TWITTER INC    26.605000    0.100000  22699.999909
# ATHN              ATHENAHEALTH INC   134.979996    0.100000  22699.999995
# TWOU                        2U INC    70.550003    0.100000  22699.999986
# MELI              MERCADOLIBRE INC   357.420013    0.059318  13465.078971
# SHOP         SHOPIFY INC - CLASS A   127.028999    0.100000  22699.999994
# NOW                 SERVICENOW INC   152.945007    0.100000  22699.999994
# TSM    TAIWAN SEMICONDUCTOR-SP ADR    42.860001    0.100000  22699.999994
# NTDOY  NINTENDO CO LTD-UNSPONS ADR    52.310001    0.020864   4736.119779
# MSFT                MICROSOFT CORP    91.195503    0.038920   8834.880766
# TDOC                   TELADOC INC    34.500000    0.080898  18363.920091
#
#            Shares
# AMZN    15.602822
# NFLX    83.985422
# TWTR   853.223075
# ATHN   168.173068
# TWOU   321.757605
# MELI    37.672986
# SHOP   178.699353
# NOW    148.419360
# TSM    529.631345
# NTDOY   90.539470
# MSFT    96.878470
# TDOC   532.287539
